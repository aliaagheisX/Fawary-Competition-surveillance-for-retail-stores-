# %%
import matplotlib.pyplot as plt

# %%
tloss = [1.04, 1.01, 0.99667, 0.99, 0.982667,    0.95, 0.95, 0.9467, 0.945, 0.946,   0.94, 0.94, 0.94, 0.94, 0.9372]
vloss = [0.9941, 0.9634, 0.9748, 0.9561, 0.9539, 0.9526, 0.9514, 0.9389, 0.9571, 0.9383, 0.9415, 0.9391, 0.9397, 0.9492, 0.9293]

steps = list(range(len(tloss)))
len(tloss), len(vloss)
# Out:
# (15, 15)

# %%
plt.plot(steps, tloss)
plt.plot(steps, vloss)

# %%
s = "فاينال"
s[::-1]
# Out:
# 'لانياف'
