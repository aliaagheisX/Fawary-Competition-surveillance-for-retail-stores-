# %%
import os
import sys
import json
from pathlib import Path
sys.path.append(os.path.abspath('..'))

from FasterRcnn.tracking import *
from dataset import df_train

# %%
img = get_frame(fnum=1)
df_train.query('vid=="02" & fnum == 1')
# Out:
#         fnum   id     x    y    w    h  conf  class  visibility vid
# 52548      1   82    95  273  117  202     1      1     0.51724  02
# 96224      1  162   936    1   56  118     0      7     0.73905  02
# 99006      1  163   308   24  138  280     0     11     1.00000  02
# 101788     1  164   415    1  100  235     0     11     1.00000  02
# 104570     1  165   497    1   85  178     0     11     1.00000  02
# 107352     1  166   559    1   72  142     0     11     1.00000  02
# 113479     1  171  1248   25   46   82     0      7     0.00000  02
# 118016     1  175  1047  153   69  190     0      7     0.72191  02
# 120798     1  176  1119  108   56  127     1      1     0.26768  02
# 126107     1  178  1153  144   63  175     1      1     0.00000  02
# 130665     1  182  1340   61   58   92     0      7     0.68817  02
# 137947     1  188  1140   48  164  319     0     11     1.00000  02
# 141240     1  190  1723  271  196  664     0     11     1.00000  02
# ...
